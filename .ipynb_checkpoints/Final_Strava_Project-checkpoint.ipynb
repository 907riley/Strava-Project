# %% [markdown]
# # The Impacts of Music (and temperature) on Running

# %% [markdown]
# I manually get the temperature for the time I run from [this](https://www.wunderground.com/history/daily/us/wa/spokane/KGEG/date/2020-11-19) webiste

# %%
# converting the .JSON to .CSV so it's easier to see the tables

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats


spotify_df = pd.read_json("StreamingHistory2.json")
spotify_df.to_csv("SpotifyHistory.csv")

playlist_df = pd.read_json("Playlist1.json")
playlist_df.to_csv("Playlists.csv")

og_strava_df = pd.read_csv("StravaFinalRuns.csv")
strava_df = og_strava_df.copy()

#print(strava_df)

# %% [markdown]
# ## Doing some cleaning

# %%
# converting the average speed and max speed from meter/second to miles/hour
for i in range(len(strava_df["Average Speed"])):
    strava_df.iloc[i, 10] = float(strava_df.iloc[i, 10]) * 2.23694
    strava_df.iloc[i, 9] = float(strava_df.iloc[i, 9]) * 2.23694

# %% [markdown]
# ## Plotting my average pace for all runs
# I used my function from DA4 where I made a function to specifically make bar graphs for my strava data. I also plot the temperature here. In the future I'll try to test to see if there is a correlation between the temperature and my running because I feel exhausted when it's too hot and I get slowed down by ice when it's too cold.

# %%
def bar_chart(x, y, title, size, attribute):
    '''
    Description: Takes in two columns/lists and plots them to a bar graph.
    Also uses the title parameter to label the graph.
    '''
    if size == "big":
        plt.figure(figsize = (20,10))
    else:
        plt.figure()
    plt.xlabel("Date")
    plt.xticks(rotation=45)
    if attribute == "Average Speed":
        plt.bar(x, y, width = .5, color = "#FC4C02", edgecolor = "black") # color is strava red
        plt.ylabel("Speed MPH")
        plt.ylim([8.2, 9.5])
    elif attribute == "Temperature":
        plt.ylabel("Temperature in Fahrenheit")
        plt.bar(x, y, width = .5, color = "#87ceeb", edgecolor = "black")
    elif attribute == "Max Speed":
        plt.bar(x, y, width = .5, color = "#FC4C02", edgecolor = "black") # color is strava red
        plt.ylabel("Speed MPH")
        plt.ylim([10, 15.5])  
    plt.title(title)
    for a, b in enumerate(y):
        plt.text(a - .25, b + .01, str("{:.2f}".format(b)))
    plt.show()  


average_speed_ser = strava_df["Average Speed"]
temperature_ser = strava_df["Temperature at Start"]
dates_ser = strava_df["Activity Date"]
for i in range(0, len(dates_ser)):
    dates_ser.loc[i] = ((dates_ser.loc[i]).split(",", maxsplit = 1)[0])

bar_chart(dates_ser, average_speed_ser, "Average Speed in Miles per Hour", "big", "Average Speed")
bar_chart(dates_ser, temperature_ser, "Temperature at Start", "big", "Temperature")
bar_chart(dates_ser, strava_df["Max Speed"], "Max Speed", "big", "Max Speed")

# %% [markdown]
# ## Box Plot to Show Data Spread

# %%
plt.figure()
plt.ylabel("Average Speed in MPH")
plt.title("Box and Whiskers Plot Showing Data Spread")
plt.boxplot(strava_df["Average Speed"], notch = True)
plt.show()

# %% [markdown]
# ## Plotting my runs based on what genre I was listening to
# I've been recording the genre of music I've been listening to while running (I made three playlists: Rap, Pop, and Folk). I want to see if the type of music I listen to has a significant impact on my running.

# %%
grouped_by_genre = strava_df.groupby("Activity Description")

folk_df = pd.DataFrame()
rap_df = pd.DataFrame()
pop_df = pd.DataFrame()


for group_name, group_df in grouped_by_genre:
    if group_name == "Pop":
        pop_df = group_df
    elif group_name == "Rap":
        rap_df = group_df
    elif group_name == "Folk":
        folk_df = group_df

    dates_ser = group_df["Activity Date"]
    bar_chart(dates_ser, group_df["Average Speed"], group_name, "small", "Average Speed")
    average_genre_speed = group_df["Average Speed"].mean()
    print("Average Speed When Listening to ", group_name, " Genre: ", average_genre_speed)
# Out:
# Average Speed When Listening to  Folk  Genre:  8.857546830598903
# Average Speed When Listening to  Pop  Genre:  8.938431559116658
# Average Speed When Listening to  Rap  Genre:  9.044166085894087

# %% [markdown]
# ## Histogram of Data
# Using functions from VisualizationFun notes
#
# When the bins used for the histogram is low (for example 9), it looks like we have a nice distribution of data

# %%
def histogram_chart_example(x, bins):
    plt.figure()
    plt.hist(x, bins = bins, facecolor = "#FC4C02", edgecolor = "black")
    plt.show()
    plt.close()

histogram_chart_example(strava_df["Average Speed"], 11)
print(strava_df["Average Speed"].mean())
# Out:
# 8.946714825203214

# %% [markdown]
# ## Hypothesis Testing
#
# Testing to see if there is a difference between the average speeds for my Rap and Folk runs with a level of significance of 0.10

# %% [markdown]
# #### Null Hypothesis
#
# $H_0: \mu_{folk} = \mu_{rap}$
# $H_1: \mu_{folk} != \mu_{rap}$
#
# #### Level of Significance
#
# $\alpha = 0.10$
#
# #### Test Statisitc
# Two tailed, independent data sets (are they independent of each other though?)
# * $ t = \frac{\bar {x_1} - \bar {x_2}}{\sqrt{S_p^2(\frac{1}{n_1} + \frac{1}{n_2})}} $
#
# #### Decision Rule
# n = 10 for folk
# n = 10 for rap
# df = 10 + 10 - 2 = 18
# t-critical for a two tailed test with df of 18 and level of significance of 0.10 is 1.734
#
# If -1.734 > t-computed or t-computed > 1.734 then reject $H_0$
# If -1.734 <= t-computed and t-computed <= 1.734 then don't reject $H_0$
#
# #### Make Decision

# %%
t_computed, p_value = stats.ttest_ind(rap_df["Average Speed"], folk_df["Average Speed"])
print(t_computed, p_value)
# Out:
# 2.3887085885664914 0.02806943342442143

# %% [markdown]
# t-computed is 2.3887 which is greater than 1.734 so reject $H_0$
# Therefore we can say that my average speeds for running while listening to rap music and folk music are different with a level of significance of 0.10
